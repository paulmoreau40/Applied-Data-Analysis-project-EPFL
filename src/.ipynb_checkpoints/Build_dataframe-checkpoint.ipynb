# %%
import pandas as pd
import bz2
import json
import re
import math

# %%
files = ['../data/Pope-quotes15.json.bz2', '../data/Pope-quotes16.json.bz2', '../data/Pope-quotes17.json.bz2', '../data/Pope-quotes18.json.bz2', '../data/Pope-quotes19.json.bz2', '../data/Pope-quotes20.json.bz2' ]
counter = 0

for file in files:
    with bz2.open(file, 'rb') as s_file:
        for instance in s_file:
            counter = counter + 1

print(counter)
# Out:
# 102993

# %% [markdown]
# ## Import JSON and build DataFrame

# %%
file = '../data/Pope-quotes15.json.bz2'
data = []

with bz2.open(file, 'rb') as s_file:
    for instance in s_file:
        instance = json.loads(instance)
        
        row = []
        row.extend([instance['quotation'],instance['speaker'], instance['probas'][0][1]])
        
        if len(instance['probas']) > 1:       #There are at least 2 speakers
            row.extend([instance['probas'][1][0], instance['probas'][1][1]])
        else:
            row.extend([math.nan, math.nan])
            
        if len(instance['probas']) > 2:       #There are at least 3 speakers
            row.extend([instance['probas'][2][0], instance['probas'][2][1]])
        else:
            row.extend([math.nan, math.nan])
               
        row.extend([instance['date'], instance['numOccurrences'], instance['phase'], instance['nbr_words'], len(instance['quotation']), len(instance['probas'])])
        
        data.append(row)
        
df_pope = pd.DataFrame(data, columns =['quote', 'speaker', 'probability', 'second_speaker', 'second_probability', 'third_speaker', 'third_probability', 'date', 'nbr_occurences', 'phase', 'nbr_words', 'nbr_characters', 'nbr_speakers'])

# %%
df_pope
# Out:
#                                                    quote       speaker  \
# 0      a good father knows how to wait, and knows how...  Pope Francis
# 1                            I don't have an ear for it,  Pope Francis
# 2      Ask `What does this say to my heart? What is G...  Pope Francis
# 3      Be praised, my Lord, through our sister Mother...  Pope Francis
# 4      But he's already taken a number of important s...  Pope Francis
# ...                                                  ...           ...
# 29185  and the banners of ISIS are not displayed toda...  Pope Francis
# 29186  as God's adopted children, brothers and sister...  Pope Francis
# 29187  Commending the late cardinal's noble soul to G...  Pope Francis
# 29188  consecrating everything, disavowing everything...  Pope Francis
# 29189  Even when the task seems too much, the resourc...  Pope Francis
#
#       probability second_speaker second_probability  third_speaker  \
# 0          0.7727           None             0.2215  Thomas Rosica
# 1          0.7834           None             0.1408     Mark Miles
# 2          0.9272           None             0.0728            NaN
# 3          0.7581           None             0.2419            NaN
# 4          0.5039           None             0.4961            NaN
# ...           ...            ...                ...            ...
# 29185      0.7026           None             0.2974            NaN
# 29186       0.573           None              0.427            NaN
# 29187      0.5264           None             0.3283    Edward Egan
# 29188      0.6653           None             0.3347            NaN
# 29189      0.9285           None             0.0715            NaN
#
#       third_probability                 date  nbr_occurences phase  nbr_words  \
# 0                0.0058  2015-02-06 15:31:07               2     E         18
# 1                0.0758  2015-09-25 01:44:00               1     E          8
# 2                   NaN  2015-12-03 21:20:49               1     E         17
# 3                   NaN  2015-06-19 00:49:49               1     E         24
# 4                   NaN  2015-07-28 19:34:53               2     E         20
# ...                 ...                  ...             ...   ...        ...
# 29185               NaN  2015-08-11 03:38:51               1     E         52
# 29186               NaN  2015-01-18 09:01:13               1     E         10
# 29187            0.1453  2015-03-06 11:10:22               1     E         13
# 29188               NaN  2015-09-04 18:29:20               1     E         21
# 29189               NaN  2015-11-27 18:41:00               1     E         26
#
#        nbr_characters  nbr_speakers
# 0                  87             3
# 1                  27             3
# 2                  82             2
# 3                 137             2
# 4                 103             2
# ...               ...           ...
# 29185             295             2
# 29186              57             2
# 29187              72             3
# 29188             155             2
# 29189             138             2
#
# [29190 rows x 13 columns]

# %% [markdown]
# ## Save as pickle

# %%
df_pope.to_pickle("../data/Pope-quotes.pkl")
